# %%
import pandas as pd

for i in range(1, 77):
    input_file = f'samples ({i}).csv'
    output_file = input_file

    # Read the CSV file
    df = pd.read_csv(input_file)

    # Remove the first row
    df = df.iloc[1:]
    # Keep only 'ML2' and 'Elapsed time' columns
    df = df[["'Elapsed time'","'ECG1'"]]
    # Save the modified DataFrame to a new CSV file
    df = df.rename(columns={"'ECG1'": 'signal', "'Elapsed time'": 'time'})

    df.to_csv(output_file, index=False)

    print(f'Removed first row from {input_file} and saved to {output_file}')
# Out:
# Removed first row from samples (1).csv and saved to samples (1).csv
# Removed first row from samples (2).csv and saved to samples (2).csv
# Removed first row from samples (3).csv and saved to samples (3).csv
# Removed first row from samples (4).csv and saved to samples (4).csv
# Removed first row from samples (5).csv and saved to samples (5).csv
# Removed first row from samples (6).csv and saved to samples (6).csv
# Removed first row from samples (7).csv and saved to samples (7).csv
# Removed first row from samples (8).csv and saved to samples (8).csv
# Removed first row from samples (9).csv and saved to samples (9).csv
# Removed first row from samples (10).csv and saved to samples (10).csv
# Removed first row from samples (11).csv and saved to samples (11).csv
# Removed first row from samples (12).csv and saved to samples (12).csv
# Removed first row from samples (13).csv and saved to samples (13).csv
# Removed first row from samples (14).csv and saved to samples (14).csv
# Removed first row from samples (15).csv and saved to samples (15).csv
# Removed first row from samples (16).csv and saved to samples (16).csv
# Removed first row from samples (17).csv and saved to samples (17).csv
# Removed first row from samples (18).csv and saved to samples (18).csv
# Removed first row from samples (19).csv and saved to samples (19).csv
# Removed first row from samples (20).csv and saved to samples (20).csv
# Removed first row from samples (21).csv and saved to samples (21).csv
# Removed first row from samples (22).csv and saved to samples (22).csv
# Removed first row from samples (23).csv and saved to samples (23).csv
# Removed first row from samples (24).csv and saved to samples (24).csv
# Removed first row from samples (25).csv and saved to samples (25).csv
# Removed first row from samples (26).csv and saved to samples (26).csv
# Removed first row from samples (27).csv and saved to samples (27).csv
# Removed first row from samples (28).csv and saved to samples (28).csv
# Removed first row from samples (29).csv and saved to samples (29).csv
# Removed first row from samples (30).csv and saved to samples (30).csv
# Removed first row from samples (31).csv and saved to samples (31).csv
# Removed first row from samples (32).csv and saved to samples (32).csv
# Removed first row from samples (33).csv and saved to samples (33).csv
# Removed first row from samples (34).csv and saved to samples (34).csv
# Removed first row from samples (35).csv and saved to samples (35).csv
# Removed first row from samples (36).csv and saved to samples (36).csv
# Removed first row from samples (37).csv and saved to samples (37).csv
# Removed first row from samples (38).csv and saved to samples (38).csv
# Removed first row from samples (39).csv and saved to samples (39).csv
# Removed first row from samples (40).csv and saved to samples (40).csv
# Removed first row from samples (41).csv and saved to samples (41).csv
# Removed first row from samples (42).csv and saved to samples (42).csv
# Removed first row from samples (43).csv and saved to samples (43).csv
# Removed first row from samples (44).csv and saved to samples (44).csv
# Removed first row from samples (45).csv and saved to samples (45).csv
# Removed first row from samples (46).csv and saved to samples (46).csv
# Removed first row from samples (47).csv and saved to samples (47).csv
# Removed first row from samples (48).csv and saved to samples (48).csv
# Removed first row from samples (49).csv and saved to samples (49).csv
# Removed first row from samples (50).csv and saved to samples (50).csv
# Removed first row from samples (51).csv and saved to samples (51).csv
# Removed first row from samples (52).csv and saved to samples (52).csv
# Removed first row from samples (53).csv and saved to samples (53).csv
# Removed first row from samples (54).csv and saved to samples (54).csv
# Removed first row from samples (55).csv and saved to samples (55).csv
# Removed first row from samples (56).csv and saved to samples (56).csv
# Removed first row from samples (57).csv and saved to samples (57).csv
# Removed first row from samples (58).csv and saved to samples (58).csv
# Removed first row from samples (59).csv and saved to samples (59).csv
# Removed first row from samples (60).csv and saved to samples (60).csv
# Removed first row from samples (61).csv and saved to samples (61).csv
# Removed first row from samples (62).csv and saved to samples (62).csv
# Removed first row from samples (63).csv and saved to samples (63).csv
# Removed first row from samples (64).csv and saved to samples (64).csv
# Removed first row from samples (65).csv and saved to samples (65).csv
# Removed first row from samples (66).csv and saved to samples (66).csv
# Removed first row from samples (67).csv and saved to samples (67).csv
# Removed first row from samples (68).csv and saved to samples (68).csv
# Removed first row from samples (69).csv and saved to samples (69).csv
# Removed first row from samples (70).csv and saved to samples (70).csv
# Removed first row from samples (71).csv and saved to samples (71).csv
# Removed first row from samples (72).csv and saved to samples (72).csv
# Removed first row from samples (73).csv and saved to samples (73).csv
# Removed first row from samples (74).csv and saved to samples (74).csv
# Removed first row from samples (75).csv and saved to samples (75).csv
# Removed first row from samples (76).csv and saved to samples (76).csv
